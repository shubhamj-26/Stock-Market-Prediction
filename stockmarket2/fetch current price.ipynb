# %%
# !pip install --upgrade lxml
# Out:
# Requirement already satisfied: lxml in c:\users\niveditha\anaconda3\envs\project\lib\site-packages (4.6.3)

# %%
from yahoo_fin import stock_info as si

print(si.get_live_price("aapl"))
 
# or Amazon
print(si.get_live_price("amzn"))
 


# get quote table back as a data frame
print(si.get_quote_table("amzn", dict_result = False))
 
# or get it back as a dictionary (default)
#si.get_quote_table("aapl")

# get most active stocks on the day
print(si.get_day_most_active())
 
# get biggest gainers
print(si.get_day_gainers())
 
# get worst performers
print(si.get_day_losers())
# Out:
# 129.63999938964844
# 3383.1298828125
#                    attribute                        value
# 0              1y Target Est                      4238.59
# 1              52 Week Range          2,630.08 - 3,554.00
# 2                        Ask              3,383.00 x 1000
# 3                Avg. Volume                    3439773.0
# 4          Beta (5Y Monthly)                         1.15
# 5                        Bid              3,373.16 x 1000
# 6                Day's Range          3,363.75 - 3,396.78
# 7                  EPS (TTM)                        52.56
# 8              Earnings Date  Jul 28, 2021 - Aug 02, 2021
# 9           Ex-Dividend Date                          NaN
# 10  Forward Dividend & Yield                    N/A (N/A)
# 11                Market Cap                       1.706T
# 12                      Open                       3384.0
# 13            PE Ratio (TTM)                        64.36
# 14            Previous Close                      3383.87
# 15               Quote Price                  3383.129883
# 16                    Volume                    2426200.0
#    Symbol                              Name  Price (Intraday)  Change  \
# 0     AMC  AMC Entertainment Holdings, Inc.            59.040  2.0400
# 1    WISH                 ContextLogic Inc.            11.270  0.0000
# 2   RLLCF          Rolls-Royce Holdings plc             0.041  0.0081
# 3    DKNG                   DraftKings Inc.            48.510 -2.1100
# 4    AAPL                        Apple Inc.           129.640 -0.8400
# ..    ...                               ...               ...     ...
# 95   BRFS                          BRF S.A.             5.940  0.2000
# 96   STAY       Extended Stay America, Inc.            20.460  0.0000
# 97     VZ       Verizon Communications Inc.            57.290  0.1100
# 98   VIPS          Vipshop Holdings Limited            20.880 -1.0900
# 99    GGB                       Gerdau S.A.             6.310 -0.0200
#
#     % Change       Volume  Avg Vol (3 month)      Market Cap  PE Ratio (TTM)
# 0       3.58  282209000.0        144008000.0   30307000000.0             NaN
# 1       0.00  140317000.0         23179000.0    6976000000.0             NaN
# 2      24.62  119702000.0          9060000.0  893829000000.0             NaN
# 3      -4.17   88028000.0         16017000.0   19484000000.0             NaN
# 4      -0.64   62746000.0         89064000.0          2.163T           29.14
# ..       ...          ...                ...             ...             ...
# 95      3.48    9731000.0          4400000.0    4826000000.0           16.92
# 96      0.00    9687000.0          4434000.0    3636000000.0           36.15
# 97      0.19   11504000.0         16940000.0  237185000000.0           12.56
# 98     -4.96    9934000.0         18200000.0   14357000000.0           13.75
# 99     -0.32    9432000.0         19896000.0   10761000000.0           12.02
#
# [100 rows x 9 columns]
#    Symbol                                  Name  Price (Intraday)   Change  \
# 0   RLLCF              Rolls-Royce Holdings plc             0.041   0.0081
# 1   TGLVY            Top Glove Corporation Bhd.             8.200   1.2000
# 2    GOEV                            Canoo Inc.            11.050   1.5900
# 3   CITAF  COSCO SHIPPING Development Co., Ltd.             0.240   0.0300
# 4    GSHD              Goosehead Insurance, Inc           112.610  12.2600
# ..    ...                                   ...               ...      ...
# 66    MRO              Marathon Oil Corporation            13.840   0.4200
# 67   PDCE                      PDC Energy, Inc.            48.960   1.4700
# 68   SBLK              Star Bulk Carriers Corp.            22.210   0.6600
# 69  CIG-C  Companhia Energética de Minas Gerais             3.380   0.1000
# 70   PACW                       PacWest Bancorp            43.600   1.2800
#
#     % Change       Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 0      24.62  119702000.0          9060000.0  8.938290e+11             NaN
# 1      17.14      73575.0            36141.0  1.640900e+10            8.07
# 2      16.81   31787000.0          5345000.0  2.624000e+09             NaN
# 3      14.29     407741.0            13465.0  5.308000e+09            7.74
# 4      12.22     798086.0           204820.0  4.196000e+09          234.60
# ..       ...          ...                ...           ...             ...
# 66      3.13   17071000.0         20864000.0  1.090800e+10             NaN
# 67      3.10     581017.0           909085.0  4.862000e+09             NaN
# 68      3.06    1853000.0          1712000.0  2.263000e+09           50.82
# 69      3.05      45109.0            28982.0  5.722000e+09            8.80
# 70      3.02     770351.0           941911.0  5.193000e+09           14.85
#
# [71 rows x 9 columns]
#    Symbol                            Name  Price (Intraday)  Change  % Change  \
# 0   CGHLY      China Gas Holdings Limited             74.26  -20.11    -21.31
# 1    SAGE         Sage Therapeutics, Inc.             58.80  -14.06    -19.30
# 2    TIGR      UP Fintech Holding Limited             23.90   -4.65    -16.29
# 3    NOVN                     Novan, Inc.             15.28   -2.07    -11.93
# 4     VRM                     Vroom, Inc.             40.01   -5.18    -11.46
# ..    ...                             ...               ...     ...       ...
# 95   UPWK                     Upwork Inc.             48.11   -2.30     -4.56
# 96   PLUG                 Plug Power Inc.             29.20   -1.37     -4.48
# 97     MP              MP Materials Corp.             31.79   -1.48     -4.45
# 98   MVIS               MicroVision, Inc.             20.42   -0.95     -4.45
# 99   SPCE  Virgin Galactic Holdings, Inc.             34.87   -1.62     -4.44
#
#         Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 0     116701.0             5315.0  1.675400e+10           12.86
# 1    8592000.0           499109.0  3.439000e+09            5.04
# 2   18204000.0          9330000.0  3.361000e+09           90.53
# 3    3876000.0          3528000.0  2.318080e+08             NaN
# 4    9964000.0          2160000.0  5.460000e+09             NaN
# ..         ...                ...           ...             ...
# 95   1359000.0          1405000.0  6.069000e+09             NaN
# 96  23442000.0         36910000.0  1.659500e+10             NaN
# 97   2507000.0          5086000.0  5.428000e+09             NaN
# 98   5700000.0         27773000.0  3.225000e+09             NaN
# 99  11732000.0         19770000.0  8.394000e+09             NaN
#
# [100 rows x 9 columns]

# %%
from lxml import html
import requests
from time import sleep
import json
import argparse
from random import randint

def parse_finance_page(ticker):
  """
  Grab financial data from NASDAQ page
  
  Args:
    ticker (str): Stock symbol
  
  Returns:
    dict: Scraped data
  """
  key_stock_dict = {}
  headers = {
        "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "Accept-Encoding":"gzip, deflate",
        "Accept-Language":"en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7",
        "Connection":"keep-alive",
        "Host":"www.nasdaq.com",
        "Referer":"http://www.nasdaq.com",
        "Upgrade-Insecure-Requests":"1",
        "User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.119 Safari/537.36"
  }

  # Retrying for failed request
  for retries in range(5):
    try:    
      url = "http://www.nasdaq.com/symbol/%s"%(ticker)
      response = requests.get(url, headers = headers, verify=False)
      
      if response.status_code!=200:
        raise ValueError("Invalid Response Received From Webserver")

      print("Parsing %s"%(url))
      # Adding random delay
      sleep(randint(1,3))   
      parser = html.fromstring(response.text)
      xpath_head = "//div[@id='qwidget_pageheader']//h1//text()"
      xpath_key_stock_table = '//div[@class="row overview-results relativeP"]//div[contains(@class,"table-table")]/div'
      xpath_open_price = '//b[contains(text(),"Open Price:")]/following-sibling::span/text()'
      xpath_open_date = '//b[contains(text(),"Open Date:")]/following-sibling::span/text()'
      xpath_close_price = '//b[contains(text(),"Close Price:")]/following-sibling::span/text()'
      xpath_close_date = '//b[contains(text(),"Close Date:")]/following-sibling::span/text()'
      xpath_key = './/div[@class="table-cell"]/b/text()'
      xpath_value = './/div[@class="table-cell"]/text()'

      raw_name = parser.xpath(xpath_head)
      key_stock_table =  parser.xpath(xpath_key_stock_table)
      raw_open_price = parser.xpath(xpath_open_price)
      raw_open_date = parser.xpath(xpath_open_date)
      raw_close_price = parser.xpath(xpath_close_price)
      raw_close_date = parser.xpath(xpath_close_date)

      company_name = raw_name[0].replace("Common Stock Quote & Summary Data","").strip() if raw_name else ''
      open_price =raw_open_price[0].strip() if raw_open_price else None
      open_date = raw_open_date[0].strip() if raw_open_date else None
      close_price = raw_close_price[0].strip() if raw_close_price else None
      close_date = raw_close_date[0].strip() if raw_close_date else None

      # Grabbing ans cleaning keystock data
      for i in key_stock_table:
        key = i.xpath(xpath_key)
        value = i.xpath(xpath_value)
        key = ''.join(key).strip() 
        value = ' '.join(''.join(value).split()) 
        key_stock_dict[key] = value

      nasdaq_data = {

              "company_name":company_name,
              "ticker":ticker,
              "url":url,
              "open price":open_price,
              "open_date":open_date,
              "close_price":close_price,
              "close_date":close_date,
              "key_stock_data":key_stock_dict
      }
      return nasdaq_data

    except Exception as e:
      print("Failed to process the request, Exception:%s"%(e))
    
import pandas as pd
from hdfs import InsecureClient
import os
client_hdfs = InsecureClient('http://localhost:50070')
df = pd.DataFrame(data = ticker)

# Writing Dataframe to hdfs
with client_hdfs.write('/in/helloworld.csv', encoding = 'utf-8') as writer:
    df.to_csv(writer)

if __name__=="__main__":


  ticker = 'amzn'
  print("Fetching data for %s"%(ticker))
  scraped_data = parse_finance_page(ticker)
  print("Writing scraped data to output file")

  with open('%s-summary.json'%(ticker),'w') as fp:
    json.dump(scraped_data,fp,indent = 4,ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-388e694f8b5f> in <module>
#      91 import os
#      92 client_hdfs = InsecureClient('http://localhost:50070')
# ---> 93 df = pd.DataFrame(data = ticker)
#      94
#      95 # Writing Dataframe to hdfs
#
# NameError: name 'ticker' is not defined

# %%
#Python program to scrape website  
#and save quotes from website 
import requests 
from bs4 import BeautifulSoup 
import csv 
import re

#Python program to scrape website  
#and save quotes from website 
import requests 
from bs4 import BeautifulSoup 
import csv 



def parsenews(vardata):  
    URL =vardata.rstrip().lstrip().strip()# "https://www.hindustantimes.com/delhi-news/protest-at-delhi-s-jama-masjid-against-citizenship-act-4-metro-stations-closed-in-area/story-q7vKj5IUdIKMExw5eGBfxI.html"
    #URL ="https://www.hindustantimes.com/delhi-news/protest-at-delhi-s-jama-masjid-against-citizenship-act-4-metro-stations-closed-in-area/story-q7vKj5IUdIKMExw5eGBfxI.html"
    print(repr(URL))
    headers = {
        "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "Accept-Encoding":"gzip, deflate",
        "Accept-Language":"en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7",
        "Connection":"keep-alive",
        "Host":"www.nasdaq.com",
        "Referer":"http://www.nasdaq.com",
        "Upgrade-Insecure-Requests":"1",
        "User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.119 Safari/537.36"
  }
    r = requests.get(URL, headers = headers, verify=False)
    print(r.text)
    soup = BeautifulSoup(r.content, 'html.parser') 
  
    quotes=[]  # a list to store quotes 
  
    table = soup.find('span', attrs = {'class':'symbol-page-header__pricing-price'}) 
    print(table)
    for ik in table:
        print(ik)


parsenews('http://www.nasdaq.com/symbol/amzn')
# Out:
# 'http://www.nasdaq.com/symbol/amzn'
# C:\Users\ADMIN\.conda\envs\project\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\ADMIN\.conda\envs\project\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#   <head>
#     <meta charset="utf-8" />
# <meta itemprop="acquia_lift:content_title" content="AMZN" />
# <meta itemprop="acquia_lift:content_type" content="page" />
# <meta itemprop="acquia_lift:page_type" content="content page" />
# <meta itemprop="acquia_lift:context_language" content="en" />
# <meta itemprop="acquia_lift:content_section" content="market-activity/stocks" />
# <meta itemprop="acquia_lift:content_keywords" content="" />
# <meta itemprop="acquia_lift:post_id" content="" />
# <meta itemprop="acquia_lift:content_uuid" content="" />
# <meta itemprop="acquia_lift:published_date" content="" />
# <meta itemprop="acquia_lift:persona" content="" />
# <meta itemprop="acquia_lift:engagement_score" content="1" />
# <meta itemprop="acquia_lift:account_id" content="NASDAQ" />
# <meta itemprop="acquia_lift:site_id" content="nasdaq_prod" />
# <meta itemprop="acquia_lift:contentOrigin" content="" />
# <meta itemprop="acquia_lift:liftAssetsURL" content="https://builder.lift.acquia.com" />
# <meta itemprop="acquia_lift:liftDecisionAPIURL" content="https://us-east-1-decisionapi.lift.acquia.com" />
# <meta itemprop="acquia_lift:authEndpoint" content="https://us-east-1-oauth2.lift.acquia.com/authorize" />
# <meta itemprop="acquia_lift:bootstrapMode" content="auto" />
# <meta itemprop="acquia_lift:contentReplacementMode" content="untrusted" />
# <script src="https://builder.lift.acquia.com/lift.js" async></script>
# <script>window.digitalData = {"pageInstanceID":"production:home:market-activity:stocks:amzn","page":{"pageInfo":{"author":null,"breadcrumbs":["home","market-activity","stocks","amzn"],"destinationURL":"https:\/\/www.nasdaq.com\/market-activity\/stocks\/amzn","entryURL":null,"onsiteSearchResults":null,"onsiteSearchTerm":null,"pageID":"home:market-activity:stocks:amzn","pageName":"amzn","pagePathLevel1":"market-activity","pagePathLevel2":"market-activity:stocks","pagePathLevel3":"market-activity:stocks:amzn","pagePathLevel4":null,"pagePathLevel5":null,"publisher":null,"referringURL":"https:\/\/www.nasdaq.com\/market-activity\/stocks\/amzn\/real-time","sysEnv":null,"timeStamp":1588490376,"refreshDisable":false},"category":{"eventType":null,"pageType":"symbol-page","videoType":null,"primaryCategory":"market-activity","subCategory":"stocks"},"attributes":{"adDisplay":false,"assetClass":["stocks"],"businessUnit":null,"campaignParameters":null,"industry":null,"quoteSymbol":["AMZN"],"region":null,"sponsored":false,"topic":null,"audience":null,"glossaryTerm":null}},"user":[{"segment":{"loginStatus":"guest","registrationStatus":"anonymous","cookieOptIn":true,"termsOptIn":false,"offersOptIn":false,"eloquaOptIn":false}}]};</script>
# <title>Amazon.com, Inc. Common Stock (AMZN) Stock Quotes | Nasdaq</title>
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:site" content="@Nasdaq" />
# <link rel="alternate" hreflang="en" href="https://www.nasdaq.com/market-activity/stocks/amzn" />
# <meta property="og:url" content="https://www.nasdaq.com/market-activity/stocks/amzn" />
# <meta property="og:title" content="AMZN" />
# <meta itemprop="acquia_lift:event_udf13" content="AMZN" />
# <meta itemprop="acquia_lift:event_udf12" content="Stocks" />
# <meta name="com.nasdaq.cms.taxonomy.pageType" content="symbol-page" />
# <meta name="com.nasdaq.cms.taxonomy.quoteSymbol" content="AMZN" />
# <meta itemprop="acquia_lift:event_udf14" content="" />
# <meta name="com.nasdaq.cms.taxonomy.assetClass" content="stocks" />
# <meta name="com.nasdaq.cms.taxonomy.region" content="" />
# <meta name="description" content="Amazon.com, Inc. Common Stock (AMZN) Stock Quotes - Nasdaq offers stock quotes &amp; market activity data for US and global markets." />
# <meta name="Generator" content="Drupal 8 (https://www.drupal.org)" />
# <meta name="MobileOptimized" content="width" />
# <meta name="HandheldFriendly" content="true" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Corporation",
#             "@id": "https://www.nasdaq.com/",
#             "url": "https://www.nasdaq.com/",
#             "name": "Nasdaq",
#             "logo": {
#                 "@type": "ImageObject",
#                 "url": "https://www.nasdaq.com/themes/nsdq/dist/assets/images/logo-half-white.svg"
#             }
#         },
#         {
#             "@type": "WebPage",
#             "breadcrumb": {
#                 "@type": "BreadcrumbList",
#                 "itemListElement": [
#                     {
#                         "@type": "ListItem",
#                         "position": 1,
#                         "name": "Home",
#                         "item": "https://www.nasdaq.com/"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 2,
#                         "name": "Market Activity",
#                         "item": "https://www.nasdaq.com/market-activity"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 3,
#                         "name": "Stocks",
#                         "item": "https://www.nasdaq.com/market-activity/stocks"
#                     }
#                 ]
#             }
#         },
#         {
#             "@type": "WebSite",
#             "name": "Nasdaq",
#             "url": "https://www.nasdaq.com/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": "https://www.nasdaq.com/search?q={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             }
#         }
#     ]
# }</script>
#
# <!-- Load Media.net below Header Bidding Partners-->
# <script type="text/javascript">
#  (function () {
#  window.advBidxc = window.advBidxc || {};
#  window.advBidxc.customerId = "8CUO5GS22"; //Media.net Customer ID
#  window.advBidxc.domain = window.location.hostname;
#  window.advBidxc.version = 5.1;
#  window.advBidxc.startTime = new Date().getTime();
#  function loadScript(tagSrc) {
#  var scriptTag = document.createElement('script'),
#  placeTag = document.getElementsByTagName("script")[0];
#  scriptTag.type = 'text/javascript';
#  scriptTag.async = true;
#  scriptTag.src = tagSrc;
#  placeTag.parentNode.insertBefore(scriptTag, placeTag);
#  }
#  var isSSL = 'https:' == document.location.protocol;
#  var mnSrc = '//hbx.media.net/bidexchange.js?cid=' + window.advBidxc.customerId + "&version=" + window.advBidxc.version + '&dn=' + window.advBidxc.domain + (isSSL ? '&https=1' : '');
#  loadScript(mnSrc);
#  })();
# </script>
#
# <!-- Load the Index Exchange JavaScript Library -->
# <script async src="//js-sec.indexww.com/ht/p/183702-142296045723403.js"></script>
#
# <script async src="//securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
#
# <!-- Load the Smart Targets script -->
# <script async type="text/javascript" src="https://ad.wsod.com/site/2caa62b3a3a0755e2cda9deea9070934/0.0.async/"></script>
#
# <!-- Load Google Auto Ads script -->
# <script data-ad-client="ca-pub-1861191755926748" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#
# <script type="text/javascript">
# // Initialize the google variables.
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# // Add a place to store the slot name variable.
# googletag.slots = googletag.slots || {};
# // Add a place to store slots that are queued/observed
# // These are slots that we already stored but waiting to be fetched
# googletag.slotsQueued = googletag.slotsQueued || {};
# </script>
#
# <script type="text/javascript">
# //Load the APS JavaScript Library
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
# //Initialize the Library
# apstag.init({
#     pubID: '3444',
#     adServer: 'googletag',
#     bidTimeout: 800
# });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [300, 250])
#                   .addSize([1024, 0], [[300, 250], [728, 90], [970, 250]])
#                   .addSize([1200, 0], [[728, 90], [970, 250], [1200, 628]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-Ou8"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageFullWidth", [[300, 250], [728, 90], [970, 250], [1200, 628]], "js-dfp-tag-Ou8")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-GuU"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_RightRailBox_2", [[300, 250], [300, 600]], "js-dfp-tag-GuU")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-qqQ"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_RightRailBox_1", [[300, 250], [300, 600]], "js-dfp-tag-qqQ")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [300, 250])
#                   .addSize([1024, 0], [[300, 250], [728, 90]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-MXc"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageTwoThirdsWidth_1", [[300, 250], [728, 90]], "js-dfp-tag-MXc")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-ejg"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_RightRail2UpButton_2", [[88, 31], [120, 60]], "js-dfp-tag-ejg")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-TYU"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Native", 'fluid', "js-dfp-tag-TYU")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-3sU"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_RightRailBox", [[300, 250], [300, 600]], "js-dfp-tag-3sU")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-v2w"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolRight_2", [[88, 31], [120, 60]], "js-dfp-tag-v2w")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-OhA"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolRight_1", [[88, 31], [120, 60]], "js-dfp-tag-OhA")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-1f8"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolLeft_2", [[88, 31], [120, 60]], "js-dfp-tag-1f8")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-6ug"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolLeft_1", [[88, 31], [120, 60]], "js-dfp-tag-6ug")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [320, 50])
#                   .addSize([768, 0], [728, 90])
#                   .addSize([1200, 0], [[728, 90], [970, 250]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-uzQ"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Leaderboard", [[320, 50], [728, 90], [970, 250]], "js-dfp-tag-uzQ")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [1, 1])
#                   .addSize([768, 0], [1, 1])
#                   .addSize([1200, 0], [1, 1])
#                 .build();
#
#     googletag.slots["js-dfp-tag-ux0"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Pixel_1", [1, 1], "js-dfp-tag-ux0")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
#       googletag.pubads().enableAsyncRendering();
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#         googletag.pubads().disableInitialLoad();
#
#   googletag.pubads().setTargeting("nasdaqdotcom_page_instance_id", digitalData.pageInstanceID || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_page_template", digitalData.page.category.pageType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_publisher", digitalData.page.pageInfo.publisher || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_page_name", digitalData.page.pageInfo.pageName || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_search_term", digitalData.page.pageInfo.onsiteSearchTerm || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_region_tag_list", (digitalData.page.attributes.region || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_topic_tag_list", (digitalData.page.attributes.topic || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_asset_class_tag_list", (digitalData.page.attributes.assetClass || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_quote_symbol_list", (digitalData.page.attributes.quoteSymbol || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_industry_tag_list", (digitalData.page.attributes.industry || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_audience_tag_lists", (digitalData.page.attributes.audience || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_video_type", digitalData.page.category.videoType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_event_type", digitalData.page.category.eventType || '');
#
#   if (typeof AcquiaLift !== 'undefined' && AcquiaLift.currentSegments) {
#     googletag.pubads().setTargeting("acquialift_segment_id", AcquiaLift.currentSegments.map(function(d){return d.id}).join(",") || "");
#   }
#
#   googletag.pubads().enableLazyLoad({
#     fetchMarginPercent: 500,
#     renderMarginPercent: 200,
#     mobileScaling: 2.0
#   });
#   googletag.enableServices();
# });
# </script>
# <link rel="shortcut icon" href="/sites/acquia.prod/files/favicon.ico" type="image/vnd.microsoft.icon" />
# <script src="/sites/acquia.prod/files/google_tag/google_tag.script.js?q9kvu1"></script>
#
#         <link rel="stylesheet" media="all" href="/sites/acquia.prod/files/css/css_tiN0lZ4avIYsodHOOEA7Z6X-mirzF19ySWTdMVoLcNg.css?q9kvu1" />
# <link rel="stylesheet" media="all" href="/sites/acquia.prod/files/css/css_EdNUwtSdjc9mwf2vNWPzaqXOKlhBOlzahg-sZAVq1AE.css?q9kvu1" />
#
#     <script type="application/json" data-drupal-selector="drupal-settings-json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"nasdaq_symbol\/2873","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en","currentQuery":{"_wrapper_format":"html"}},"pluralDelimiter":"\u0003","jquery":{"ui":{"datepicker":{"isRTL":false,"firstDay":0}}},"ajaxPageState":{"libraries":"core\/html5shiv,datalayer\/behaviors,external_link_popup\/dialog,lr_ciam\/drupal.ciam_core,lr_ciam\/drupal.ciam_custom,nsdq\/ads,nsdq\/arrow-cta,nsdq\/carousel-controls,nsdq\/company-executives,nsdq\/company-profile,nsdq\/featured-notification-bar,nsdq\/find-symbol,nsdq\/footer-form,nsdq\/form,nsdq\/global,nsdq\/grid-guides,nsdq\/header-ads,nsdq\/inline-card-stack,nsdq\/loader-overlay,nsdq\/modal,nsdq\/module-header,nsdq\/news-two-column,nsdq\/quote-detail,nsdq\/quote-detail-nav,nsdq\/quote-page-chart,nsdq\/search-overlay,nsdq\/similar-companies,nsdq\/summary-data,nsdq\/svg-loader,nsdq\/symbol-graph,nsdq\/symbol-page-header,nsdq\/symbol-ticker,nsdq\/table-tabs,nsdq\/watchlist,nsdq_admin\/toolbar,paragraphs\/drupal.paragraphs.unpublished,system\/base","theme":"nsdq","theme_token":null},"ajaxTrustedUrl":[],"dataLayer":{"defaultLang":"en","languages":{"en":{"id":"en","name":"English","direction":"ltr","weight":0}}},"external_link_popup":{"whitelist":"nasdaqtrader.com,nasdaqomxnordic.com,nasdaqbaltic.com,nasdaqcsd.com,vbsi.is,nasdaq.net,evestment.com,quandl.com,cinnober.com,listingcenter.nasdaq.com,indexes.nasdaqomx.com,ir.nasdaq.com,dorseywright.com,ec.boardvantage.com,secure.directorsdesk.com,nasdaqomx.com,cnbc.com,politico.com,morningmoney428.splashthat.com,finance.yahoo.com","width":"85%","popups":[{"id":"default","name":"Default","status":true,"weight":10,"close":true,"title":"You are now leaving Nasdaq.com","body":"\u003Cp\u003EBy clicking this link you are leaving Nasdaq.com and proceeding to an external site operated by a third-party client and\/or vendor. Nasdaq, Inc. is not responsible for the content of these sites, and their privacy policy and security may be different than Nasdaq.com.\u003C\/p\u003E\n","labelyes":"Continue","labelno":"Back","domains":"*"}]},"ciam":{"verificationUrl":"https:\/\/www.nasdaq.com\/user\/login","resetPasswordUrl":"https:\/\/www.nasdaq.com\/user\/login","loggedIn":false,"accessToken":[],"phoneId":"","appName":"nasdaq","apiKey":"e77a8cb5-d7ad-4ce9-8ae5-6e7524edf5f3","autoHideTime":"","appPath":"\/","callback":"https:\/\/www.nasdaq.com\/user\/ciamlogin?destination=\/market-activity\/stocks\/amzn%3F_wrapper_format%3Dhtml","home":"https:\/\/www.nasdaq.com\/","sott":"","debugMode":false,"tokenType":"jwt","integrationName":"Nasdaq JWT"},"company_profile":{"AMZN":{"title":"Company Description","name":"","description":null,"details":{"sector":null,"industry":null,"region":"","ipo_date":null,"ipo_price":"","exchange":"NASDAQ-GS","ceo":"","full_time_employees":""},"company_fundamentals":[{"title":"SEC Filings","url":"\/market-activity\/stocks\/amzn\/sec-filings"},{"title":"Financials","url":"\/market-activity\/stocks\/amzn\/financials"},{"title":"Insider Activity","url":"\/market-activity\/stocks\/amzn\/insider-activity"},{"title":"Institutional Holdings","url":"\/market-activity\/stocks\/amzn\/institutional-holdings"}],"key_executives":[],"address":"","phone":"","site":"","site_short":null,"social":{"channels":[]},"asset_class":"Stocks"}},"user":{"uid":0,"permissionsHash":"dd020992b4c5dc78b8a91d5f2bac00f311c736cbd4f618f0f90bfb118b671df5"}}</script>
#
# <!--[if lte IE 8]>
# <script src="/sites/acquia.prod/files/js/js_VtafjXmRvoUgAzqzYTA3Wrjkx9wcWhjP0G4ZnnqRamA.js"></script>
# <![endif]-->
# <script src="/sites/acquia.prod/files/js/js_Khc_2yUd0V8QCJwUvrJlTzb8loPGPDvlbipgbtYu2u4.js"></script>
#
#     <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#     <link rel="manifest" href="/manifest.json">
#     <meta name="msapplication-TileColor" content="#da532c">
#     <meta name="theme-color" content="#ffffff">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <meta name="google-site-verification" content="A4ZdzztVttv1nCpL1SePVC3K2K">
#
#         <!-- 33Across Header Tag -->
#     <script>if (document.cookie.indexOf('accept-cookies=') == -1) {
#     console.log('No consent yet - Consent box should appear');
#     }
#     else{
#     var Tynt=Tynt||[];Tynt.push('doG6GOFzCr6ykKaKkv7mNO');
#     Tynt.cmd=Tynt.cmd||[];Tynt.cmd.push(function(){
#     Tynt.ads.display('','','inview');});
#     (function(){var h,s=document.createElement('script');
#     s.src=(window.location.protocol==='https:'?
#     'https':'http')+'://cdn.tynt.com/rciv.js';
#     h=document.getElementsByTagName('script')[0];
#     h.parentNode.insertBefore(s,h);})();
#     }</script>
#
#           <!—- content:32847 -->
#
#     <!-- FAQ schema markup for direct listing page -->
#
#   <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"true","rua.cpush":"false","rua.upre":"true","rua.cpre":"true","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"SJ-7a13a0d6-ea0c-4c2b-87ea-e46d8c18efae","rua.cook":"true","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false"}]);</script>
#   <script>!function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="JMQ95-CD7GZ-6S8JD-G393D-PHU4L",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,o,_,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",_=document.getElementsByTagName("script")[0],_.parentNode.insertBefore(r,_);try{o=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",o=r.contentWindow.document}o.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"JMQ95-CD7GZ-6S8JD-G393D-PHU4L",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},o.write("<bo"+'dy onload="document._l();">'),o.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e="true"=="true"?1:0,t="cookiepresent",n="wyyngp3ipiamgxvosizq-f-38f897d24-clientnsv4-s.akamaihd.net",i={"ak.v":"27","ak.cp":"841979","ak.ai":parseInt("537243",10),"ak.ol":"0","ak.cr":19,"ak.ipv":4,"ak.proto":"","ak.rid":"161d09bb","ak.r":26813,"ak.a2":e,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"182.48.211.0","ak.cport":42925,"ak.gh":"173.223.235.204","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"fast","ak.t":"1588498995","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"49"};if(""!==t)i["ak.ruds"]=t;var o={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))i["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!o.i){var a=BOOMR.subscribe;a("before_beacon",o.av,null,null),a("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script><script>bazadebezolkohpepadr="2005846873"</script><script type="text/javascript" src="https://www.nasdaq.com/akam/11/778ec962" defer></script></head>
#   <body class="path-nasdaq-symbol with-header-ads">
#         <a href="#main-content" class="jumpnav">Skip to main content</a>
#     <noscript aria-hidden="true"><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-TB9QCTB&amp;gtm_auth=AbgJsDZWx9ClJu0CVnQWXA&amp;gtm_preview=env-10&amp;gtm_cookies_win=x" height="0" width="0" title="Google Tag Manager"></iframe></noscript>
#       <div class="header-ads">
#     <div class="header-ads__left">
#           </div>
#     <div class="header-ads__center">
#       <div class="ads__header-ad-pixel-3-up">
#       <div class="ads__header-ad-pixel-3-up__pixel">
#
# <div id="js-dfp-tag-ux0"  class="atf-pixel-1">
#
#     <script type="text/javascript">
#         googletag.cmd.push(function() {
#             googletag.display('js-dfp-tag-ux0');
#         });
#     </script>
# </div>
#
#     </div>
#   </div>
#
#
#       <div class="">
# <div id="js-dfp-tag-uzQ"  class="atf-leaderboard-quotes">
#
#     <script type="text/javascript">
#         googletag.cmd.push(function() {
#             googletag.display('js-dfp-tag-uzQ');
#         });
#     </script>
# </div>
# </div>
#
#
#
#     </div>
#     <div class="header-ads__right">
#           </div>
#   </div>
#
#
#       <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas>
#
# <div class="page with-primary-nav">
#
#   <div class="header-group">
#
#
#
#
# <header class="primary-nav  primary-nav--sticky " data-mega-menu-disabled="FALSE" role="banner">
#   <nav class="primary-nav__content" aria-label="Primary Navigation" role="navigation">
#     <button class="primary-nav__hamburger" aria-label="Toggle mobile navigation menu"></button>
#
#     <div class="primary-nav__logo">
#       <a href="/" title="Nasdaq Homepage">
#         <img class="primary-nav__logo-normal" src="/themes/nsdq/dist/assets/images/logo.svg" alt="Nasdaq Logo" />
#               </a>
#     </div>
#
#     <ul class="primary-nav__links" aria-hidden="true" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#
#
#
#         <li class="primary-nav__link " itemprop="name">
#           <a class="primary-nav__anchor" data-mega-menu-enabled="true" href="/market-activity" title="" itemprop="url">
#             <span class="primary-nav__anchor-text">Market Activity</span>
#           </a>
#                       <button class="primary-nav__expand" data-enabled="false" aria-label="Market Activity - Click to open sub-navigation">
#               <span class="primary-nav__expand-caret" aria-hidden="true"></span>
#             </button>
#             <div class="primary-nav__mega" aria-hidden="true" >
#   <ul class="primary-nav__mega-list" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#
#           <li class="primary-nav__mega-column" itemprop="name">
#
#                       <div class="primary-nav__cta" tabindex="0">
#               <a class="primary-nav__cta-link" href="/market-activity" itemprop="url">
#                 <span class="primary-nav__cta-text">See All Market Activity</span>
#                 <span class="primary-nav__cta-arrow" aria-hidden="true"></span>
#               </a>
#             </div>
#
#
#
#
#
#
#                       <span class="primary-nav__header">
#                               <a class="primary-nav__header-link" href="/market-activity" itemprop="url">
#                   <span class="primary-nav__header-link-text">Market Activity</span>
#                   <span class="primary-nav__header-link-caret" aria-hidden="true"></span>
#                 </a>
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/stocks" itemprop="url">Stocks</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/funds-and-etfs" itemprop="url">Funds + ETFs</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/indexes" itemprop="url">Indexes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/commodities" itemprop="url">Commodities</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/cryptocurrency" itemprop="url">Cryptocurrency</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/currencies" itemprop="url">Currencies</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/futures" itemprop="url">Futures</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/fixed-income" itemprop="url">Fixed Income</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               Quick Links
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/quotes/real-time" itemprop="url">Real-Time Quotes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/after-hours" itemprop="url">After-Hours Quotes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/pre-market" itemprop="url">Pre-Market Quotes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/quotes/nasdaq-ndx-index" itemprop="url">Nasdaq-100</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/stocks/screener" itemprop="url">Symbol Screener</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/online-brokers" itemprop="url">Online Brokers</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/glossary" itemprop="url">Glossary</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/fixed-income/nasdaq-sustainable-bond-network" itemprop="url">Sustainable Bond Network</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               Market Events
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/economic-calendar" itemprop="url">Economic Calendar</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/earnings" itemprop="url">Earnings</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/ipos" itemprop="url">IPO Calendar</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/dividends" itemprop="url">Dividends</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/stock-splits" itemprop="url">Stock Splits</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/spos" itemprop="url">SPO Calendar</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               <a class="primary-nav__header-link" href="https://www.nasdaq.com/market-activity/commodities" itemprop="url">
#                   <span class="primary-nav__header-link-text">Commodities</span>
#                   <span class="primary-nav__header-link-caret" aria-hidden="true"></span>
#                 </a>
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/commodities/GCCMX" itemprop="url">Gold</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/commodities/HGCMX" itemprop="url">Copper</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/commodities/CLNMX" itemprop="url">Crude Oil</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/commodities/NGNMX" itemprop="url">Natural Gas</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#       </ul>
#
#   </div>
#                   </li>
#
#
#
#         <li class="primary-nav__link " itemprop="name">
#           <a class="primary-nav__anchor" data-mega-menu-enabled="true" href="/news-and-insights" title="" itemprop="url">
#             <span class="primary-nav__anchor-text">News + Insights</span>
#           </a>
#                       <button class="primary-nav__expand" data-enabled="false" aria-label="News + Insights - Click to open sub-navigation">
#               <span class="primary-nav__expand-caret" aria-hidden="true"></span>
#             </button>
#             <div class="primary-nav__mega" aria-hidden="true" >
#   <ul class="primary-nav__mega-list" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#
#           <li class="primary-nav__mega-column" itemprop="name">
#
#                       <div class="primary-nav__cta" tabindex="0">
#               <a class="primary-nav__cta-link" href="/news-and-insights" itemprop="url">
#                 <span class="primary-nav__cta-text">See All News + Insights</span>
#                 <span class="primary-nav__cta-arrow" aria-hidden="true"></span>
#               </a>
#             </div>
#
#
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-subnav" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/markets" itemprop="url">Markets</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/company-intel" itemprop="url">Companies</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="https://www.nasdaq.com/news-and-insights/coronavirus" itemprop="url">Coronavirus</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/technology" itemprop="url">Technology</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/personal-finance" itemprop="url">Personal Finance</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="https://www.nasdaq.com/news-and-insights/financial-advisors" itemprop="url">Financial Advisors</a>
#                 </li>
#                           </ul>
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               Topics
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/technology/blockchain" itemprop="url">Blockchain</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/markets/commodities" itemprop="url">Commodities</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/markets/cryptocurrencies" itemprop="url">Cryptocurrencies</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/companies/earnings" itemprop="url">Earnings</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/news-and-insights/governance-center" itemprop="url">Governance</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/companies/ipos" itemprop="url">IPOs</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/personal-finance/retirement" itemprop="url">Retirement</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/markets/stocks" itemprop="url">Stocks</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               Features
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/CoronavirusWatchSignUp" itemprop="url">Coronavirus Watch Newsletter </a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/COVID-Response" itemprop="url">COVID-19: Companies Respond</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/news-and-insights/cultural-capital-video-series" itemprop="url">Cultural Capital</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-makers/subscribe" itemprop="url">Market Makers by Phil Mackintosh</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/podcasts/TotalMarkets" itemprop="url">TotalMarkets Podcast</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/news-and-insights/tradetalks" itemprop="url">TradeTalks</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/videos" itemprop="url">Nasdaq Watch</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#       </ul>
#
#   </div>
#                   </li>
#
#
#
#         <li class="primary-nav__link " itemprop="name">
#           <a class="primary-nav__anchor" data-mega-menu-enabled="true" href="/solutions" title="" itemprop="url">
#             <span class="primary-nav__anchor-text">Solutions</span>
#           </a>
#                       <button class="primary-nav__expand" data-enabled="false" aria-label="Solutions - Click to open sub-navigation">
#               <span class="primary-nav__expand-caret" aria-hidden="true"></span>
#             </button>
#             <div class="primary-nav__mega" aria-hidden="true" >
#   <ul class="primary-nav__mega-list" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#
#           <li class="primary-nav__mega-column" itemprop="name">
#
#                       <div class="primary-nav__cta" tabindex="0">
#               <a class="primary-nav__cta-link" href="/solutions" itemprop="url">
#                 <span class="primary-nav__cta-text">See All Solutions</span>
#                 <span class="primary-nav__cta-arrow" aria-hidden="true"></span>
#               </a>
#             </div>
#
#
#
#
#
#
#                       <span class="primary-nav__header">
#                               <a class="primary-nav__header-link" href="/solutions/raise-access-capital" itemprop="url">
#                   <span class="primary-nav__header-link-text">Raise &amp; Access Capital</span>
# ...
# </div>
#
#
#
#             <div class="footer__form-success">
#               <span class="footer__form-success-check"></span>
#               Thanks for submitting!
#             </div>
#           </div>
#         </fieldset>
#       </div>
#
#     <div class="footer__links">
#       <ul class="footer__links-primary">
#                   <li class="footer__link-primary">
#             <a href="http://ir.nasdaq.com/" title="Nasdaq Investor Relations Information">
#               Investor Relations
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/contact-us" title="Contact Nasdaq">
#               Contact
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/about/careers" title="Careers at Nasdaq">
#               Careers
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/mediakit" title="">
#               Advertise
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/marketsite" title="">
#               Nasdaq MarketSIte
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/trust-center" title="">
#               Trust Center
#             </a>
#           </li>
#               </ul>
#
#       <ul class="footer__links-secondary">
#                   <li class="footer__link-secondary">
#             <a href="/privacy-statement" title="">
#               Privacy
#             </a>
#           </li>
#                   <li class="footer__link-secondary">
#             <a href="/cookie-statement" title="">
#               Cookies
#             </a>
#           </li>
#                   <li class="footer__link-secondary">
#             <a href="/legal" title="">
#               Legal
#             </a>
#           </li>
#                   <li class="footer__link-secondary">
#             <a href="https://www.nasdaq.com/ccpa" title="(CA Residents Only)">
#               Do Not Sell My Personal Information (CA Residents Only)
#             </a>
#           </li>
#               </ul>
#     </div>
#
#     <ul class="footer__links-social">
#               <li class="footer__link-social">
#           <a href="https://www.facebook.com/Nasdaq/" title="Visit NASDAQ on Facebook" aria-label="Facebook"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://twitter.com/Nasdaq" title="Visit NASDAQ on Twitter" aria-label="Twitter"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://www.linkedin.com/company/nasdaq/" title="Visit NASDAQ on LinkedIn" aria-label="LinkedIn"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://www.instagram.com/nasdaq" title="Visit NASDAQ on Instagram" aria-label="Instagram"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://www.pinterest.com/nasdaq/" title="Visit NASDAQ on Pinterest" aria-label="Pinterest"></a>
#         </li>
#           </ul>
#
#     <a href="/" class="footer__logo">
#       <img src="/themes/nsdq/dist/assets/images/logo-half-white.svg" alt="Nasdaq Logo" />
#     </a>
#
#     <p class="footer__legal">&copy; 2020, Nasdaq, Inc. All Rights Reserved.</p>
#   </div>
# </footer>
#
#
#
#
#
#
#
#     </footer>
#
#       <section class="watchlist" data-initial-open="false">
#   <button class="watchlist__button" aria-label="Open Watchlist">
#     <span class="watchlist__button-icon" aria-hidden="true"></span>
#     <span class="watchlist__button-text">Watchlist</span>
#     <div class="watchlist__button-toggle" aria-hidden="true"></div>
#   </button>
#
#   <div class="watchlist__content" aria-hidden="true">
#     <header class="watchlist__content-header">
#       <button class="watchlist__add" aria-label="Add a Symbol">Add a Symbol</button>
#       <a href="https://portfolio.nasdaq.com" class="watchlist__portfolio">My Portfolio</a>
#       <button class="watchlist__close" aria-label="Close Watchlist"></button>
#       <button class="watchlist__edit" aria-label="Edit Watchlist">Edit</button>
#     </header>
#
#     <div class="watchlist__symbols">
#
#       <div class="watchlist__glide glide">
#
#
#
# <div class="carousel-controls" data-glide-el="controls">
#   <div class="carousel-controls__prev" data-glide-dir="<">
#
#
#
#
#
#
#   <button class="arrow-cta" aria-label="Previous">
#
#   <span class="arrow-cta__text" aria-label=""></span>
#   <span class="arrow-cta__icon" aria-hidden="true"></span>
#
#   </button>
#
#
#   </div>
#
#   <div class="carousel-controls__count" data-glide-el="count">
#     <span class="carousel-controls__current" data-glide-el="current"></span>/<span class="carousel-controls__total" data-glide-el="total"></span>
#   </div>
#
#   <div class="carousel-controls__next" data-glide-dir=">">
#
#
#
#
#
#
#   <button class="arrow-cta" aria-label="Next">
#
#   <span class="arrow-cta__text" aria-label=""></span>
#   <span class="arrow-cta__icon" aria-hidden="true"></span>
#
#   </button>
#
#
#   </div>
# </div>
#
#
#
#         <div class="watchlist__track glide__track" data-glide-el="track">
#           <ul class="watchlist__slides glide__slides">
#
#             <li class="watchlist__slide glide__slide watchlist__slide--add">
#               <button aria-label="Add a Symbol"></button>
#             </li>
#
#                         <li class="watchlist__slide glide__slide watchlist__slide--clone" aria-hidden="true">
#               <button class="watchlist__slide-remove" aria-hidden="true" aria-label="Remove from Watchlist"></button>
#               <span class="watchlist__slide-icon" aria-hidden="true"></span>
#               <a class="watchlist__slide-link">
#                 <span class="watchlist__slide-name"></span>
#                 <p class="watchlist__slide-price"></p>
#                 <p class="watchlist__slide-change-container">
#                   <span class="watchlist__slide-change"></span>
#                   <span class="watchlist__slide-change-percent"></span>
#                 <p>
#               </a>
#               <div class="watchlist__slide-overlay" aria-hidden="true"></div>
#             </li>
#                       </ul>
#         </div>
#       </div>
#     </div>
#
#     <div class="watchlist__empty" aria-hidden="true">
#       <span class="watchlist__empty-text">Your Watchlist is empty.</span>
#       <button class="watchlist__empty-add" aria-label="Add a Symbol">Add a Symbol</button>
#       <button class="watchlist__empty-close" aria-label="Close Watchlist"></button>
#     </div>
#
#     <div class="watchlist__loader" aria-hidden="true">
#
#
#
#
# <div class="svg-loader" style="width: 120px;">
#   <div class="svg-loader__container">
#     <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
#     viewBox="0 0 70 60" xml:space="preserve">
#       <style type="text/css">
#         .st0 {
#           fill: #0090BA;
#         }
#       </style>
#       <defs>
#         <linearGradient id="mask-gradient-1073028603" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="10%" stop-color="white" stop-opacity="0" />
#           <stop offset="20%" stop-color="white" stop-opacity="1" />
#           <stop offset="100%" stop-color="white" stop-opacity="1" />
#           <stop offset="110%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-816604088" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="20%" stop-color="white" stop-opacity="0" />
#           <stop offset="25%" stop-color="white" stop-opacity="1" />
#           <stop offset="75%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-1744094366" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="-10%" stop-color="white" stop-opacity="0" />
#           <stop offset="0%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="1" />
#           <stop offset="90%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <mask id="mask-1073028603">
#           <rect class="rect-mask__first" x="0" y="-1" width="35" height="75" fill="url(#mask-gradient-1073028603)" />
#         </mask>
#         <mask id="mask-816604088">
#           <rect class="rect-mask__second" x="27" y="10" width="16" height="40" fill="url(#mask-gradient-816604088)" />
#         </mask>
#         <mask id="mask-1744094366">
#           <rect class="rect-mask__third" x="35" y="-10" width="35" height="75" fill="url(#mask-gradient-1744094366)" />
#         </mask>
#       </defs>
#       <path class="st0" mask="url(#mask-1073028603)" d="M34.9,14.9L34.9,14.9c-1.2,0.1-2.3,0.9-2.7,2L16.7,59.6H0l15.5-42.7c0.4-1.1,1.5-2,2.8-2H34.9"/>
#       <path class="st0" mask="url(#mask-816604088)" d="M33.6,44c-1.2,0-2.1-0.7-2.6-1.7l-3.3-9.2l5.7-15.7c0.1-0.3,0.3-0.6,0.4-0.7c0.5-0.7,1.3-1.2,2.3-1.2
#   c1.2,0,2.2,0.7,2.6,1.7l3.3,9.1l-5.7,15.7c-0.1,0.4-0.3,0.6-0.4,0.7C35.4,43.5,34.6,44,33.6,44z"/>
#       <path class="st0" mask="url(#mask-1744094366)" d="M35,44.6L35,44.6c1.2-0.1,2.1-0.9,2.5-2L53,0h16.7L54.1,42.7c-0.4,1.1-1.5,2-2.8,2H35"/>
#
#     </svg>
#   </div>
# </div>
#
#
#     </div>
#   </div>
# </section>
#
# <section class="watchlist-add-overlay" aria-hidden="true">
#   <div class="watchlist-add-overlay__content">
#     <header class="watchlist-add-overlay__header">
#       <button class="watchlist-add-overlay__back" aria-label="Back"><span class="watchlist-add-overlay__back-text">Back</span></button>
#       <button class="watchlist-add-overlay__close" aria-label="Close Watchlist"></button>
#     </header>
#
#     <form class="watchlist-add-overlay__form">
#       <label class="watchlist-add-overlay__label">Add a symbol to your watchlist</label>
#       <div class="watchlist-add-overlay__input-wrapper">
#         <input class="watchlist-add-overlay__input" placeholder="Enter Symbol">
#       </div>
#     </form>
#
#     <div class="watchlist-add-overlay__unavailable">
#       <button class="watchlist-add-overlay__unavailable-close"></button>
#       <span class="watchlist-add-overlay__unavailable-text"></span>
#     </div>
#
#     <div class="watchlist-add-overlay__results watchlist-add-overlay__results">
#       <header class="watchlist-add-overlay__results-header">Most Active</header>
#       <ul class="watchlist-add-overlay__results-items"></ul>
#                         <li class="watchlist-add-overlay__results-item watchlist-add-overlay__results-item--clone" aria-hidden="true">
#         <span class="watchlist-add-overlay__symbol"></span>
#         <span class="watchlist-add-overlay__name"></span>
#         <button class="watchlist-add-overlay__add" aria-label="Add to Watchlist" data-symbol=""></button>
#       </li>
#
#       <div class="watchlist-add-overlay__loader" aria-hidden="true">
#
#
#
#
# <div class="svg-loader" style="width: 120px;">
#   <div class="svg-loader__container">
#     <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
#     viewBox="0 0 70 60" xml:space="preserve">
#       <style type="text/css">
#         .st0 {
#           fill: #0090BA;
#         }
#       </style>
#       <defs>
#         <linearGradient id="mask-gradient-2121507599" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="10%" stop-color="white" stop-opacity="0" />
#           <stop offset="20%" stop-color="white" stop-opacity="1" />
#           <stop offset="100%" stop-color="white" stop-opacity="1" />
#           <stop offset="110%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-79684692" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="20%" stop-color="white" stop-opacity="0" />
#           <stop offset="25%" stop-color="white" stop-opacity="1" />
#           <stop offset="75%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-1643611990" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="-10%" stop-color="white" stop-opacity="0" />
#           <stop offset="0%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="1" />
#           <stop offset="90%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <mask id="mask-2121507599">
#           <rect class="rect-mask__first" x="0" y="-1" width="35" height="75" fill="url(#mask-gradient-2121507599)" />
#         </mask>
#         <mask id="mask-79684692">
#           <rect class="rect-mask__second" x="27" y="10" width="16" height="40" fill="url(#mask-gradient-79684692)" />
#         </mask>
#         <mask id="mask-1643611990">
#           <rect class="rect-mask__third" x="35" y="-10" width="35" height="75" fill="url(#mask-gradient-1643611990)" />
#         </mask>
#       </defs>
#       <path class="st0" mask="url(#mask-2121507599)" d="M34.9,14.9L34.9,14.9c-1.2,0.1-2.3,0.9-2.7,2L16.7,59.6H0l15.5-42.7c0.4-1.1,1.5-2,2.8-2H34.9"/>
#       <path class="st0" mask="url(#mask-79684692)" d="M33.6,44c-1.2,0-2.1-0.7-2.6-1.7l-3.3-9.2l5.7-15.7c0.1-0.3,0.3-0.6,0.4-0.7c0.5-0.7,1.3-1.2,2.3-1.2
#   c1.2,0,2.2,0.7,2.6,1.7l3.3,9.1l-5.7,15.7c-0.1,0.4-0.3,0.6-0.4,0.7C35.4,43.5,34.6,44,33.6,44z"/>
#       <path class="st0" mask="url(#mask-1643611990)" d="M35,44.6L35,44.6c1.2-0.1,2.1-0.9,2.5-2L53,0h16.7L54.1,42.7c-0.4,1.1-1.5,2-2.8,2H35"/>
#
#     </svg>
#   </div>
# </div>
#
#
#       </div>
#     </div>
#   </div>
# </section>
#
# <div class="watchlist-live-region" role="alert" aria-live="assertive" aria-atomic="true" aria-relevant="all"></div>
#
#
#
# </div>
#   </div>
#
#
#     <script src="/sites/acquia.prod/files/js/js_2JSkzvlyXCFBJPH3xzhdbjQxL9xWKBOBY0ep1TJ5l3w.js"></script>
# <script src="/themes/nsdq/dist/react.vendor.js?q9kvu1"></script>
# <script src="/sites/acquia.prod/files/js/js_m46NkH06FpKARbpR7Utk72rI5reZjcfBGeVSSLN9ezw.js"></script>
# <script src="/themes/nsdq/dist/highcharts.js?q9kvu1"></script>
# <script src="/sites/acquia.prod/files/js/js_2JIR676ZR4DdUnMBX720PlKoWONg1AeFbLqUuMqPxqo.js"></script>
#
#     <div class="grid-guides">
#   <div class="grid-guides__container">
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#   </div>
# </div>
#
#   <noscript><img src="https://www.nasdaq.com/akam/11/pixel_778ec962?a=dD1iNGFlMDZlODgxZWM0ZTE5NmI1ZjdhOWRkNWQ0YWMwNGEzZGRhMjVkJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;" /></noscript></body>
# </html>
#
# <span class="symbol-page-header__pricing-price"></span>
